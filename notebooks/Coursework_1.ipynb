# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework1.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for num_epochs epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')
    ax_1.set_ylabel('Error')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    ax_2.set_xlabel('Accuracy')
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider, EMNISTDataProvider

# Seed a random number generator
seed = 11102019 
rng = np.random.RandomState(seed)
batch_size = 100
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x00000249F96E66A0>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x00000249F96E6C40>)

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

# Create model with ONE hidden layer
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %%
# Create model with TWO hidden layers
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # first hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), # second hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 32

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
stats_hidden_dim_32, keys_hidden_dim_32, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 0.8s to complete
#     error(train)=1.23e+00, acc(train)=6.56e-01, error(valid)=1.23e+00, acc(valid)=6.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 0.8s to complete
#     error(train)=1.12e+00, acc(train)=6.84e-01, error(valid)=1.13e+00, acc(valid)=6.77e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 0.8s to complete
#     error(train)=1.04e+00, acc(train)=7.06e-01, error(valid)=1.06e+00, acc(valid)=7.03e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 0.8s to complete
#     error(train)=9.74e-01, acc(train)=7.21e-01, error(valid)=9.98e-01, acc(valid)=7.16e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 1.2s to complete
#     error(train)=9.34e-01, acc(train)=7.32e-01, error(valid)=9.63e-01, acc(valid)=7.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 1.6s to complete
#     error(train)=9.02e-01, acc(train)=7.39e-01, error(valid)=9.31e-01, acc(valid)=7.33e-01
# ...

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 64

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
stats_hidden_dim_64, keys_hidden_dim_64, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 1.9s to complete
#     error(train)=1.06e+00, acc(train)=7.02e-01, error(valid)=1.07e+00, acc(valid)=6.99e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 1.8s to complete
#     error(train)=8.93e-01, acc(train)=7.40e-01, error(valid)=9.19e-01, acc(valid)=7.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 2.1s to complete
#     error(train)=7.89e-01, acc(train)=7.68e-01, error(valid)=8.22e-01, acc(valid)=7.62e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 2.1s to complete
#     error(train)=7.37e-01, acc(train)=7.80e-01, error(valid)=7.76e-01, acc(valid)=7.70e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 2.0s to complete
#     error(train)=6.87e-01, acc(train)=7.92e-01, error(valid)=7.34e-01, acc(valid)=7.77e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 1.9s to complete
#     error(train)=6.46e-01, acc(train)=8.05e-01, error(valid)=7.02e-01, acc(valid)=7.89e-01
# ...

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
stats_hidden_dim_128, keys_hidden_dim_128, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.4s to complete
#     error(train)=9.19e-01, acc(train)=7.38e-01, error(valid)=9.35e-01, acc(valid)=7.34e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.0s to complete
#     error(train)=7.30e-01, acc(train)=7.80e-01, error(valid)=7.62e-01, acc(valid)=7.68e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.3s to complete
#     error(train)=6.18e-01, acc(train)=8.07e-01, error(valid)=6.63e-01, acc(valid)=7.91e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.4s to complete
#     error(train)=5.50e-01, acc(train)=8.28e-01, error(valid)=6.06e-01, acc(valid)=8.09e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.3s to complete
#     error(train)=5.12e-01, acc(train)=8.37e-01, error(valid)=5.78e-01, acc(valid)=8.16e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.3s to complete
#     error(train)=4.83e-01, acc(train)=8.44e-01, error(valid)=5.59e-01, acc(valid)=8.24e-01
# ...

# %%
def plot_stats_hidden_dim(stats_hidden_dim_32, stats_hidden_dim_64, stats_hidden_dim_128, keys, stats_interval):
    
    width_2_stats = {32: stats_hidden_dim_32, 64: stats_hidden_dim_64, 128: stats_hidden_dim_128}
    
    # Plot the change in the validation and training set accuracy over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        for width in [32, 64, 128]:
            if k == 'acc(train)':
                ax_1.plot(np.arange(1, width_2_stats[width].shape[0]) * stats_interval, 
                  width_2_stats[width][1:, keys[k]], label=f'width {width}(train)')
            else:
                ax_1.plot(np.arange(1, width_2_stats[width].shape[0]) * stats_interval, 
                  width_2_stats[width][1:, keys[k]], '--', label=f'width {width}(valid)')
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')
    ax_1.set_ylabel('Accuracy')
    
    # Plot the change in the validation and training set error over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        for width in [32, 64, 128]:
            if k == 'error(train)':
                ax_2.plot(np.arange(1, width_2_stats[width].shape[0]) * stats_interval, 
                      width_2_stats[width][1:, keys[k]], label=f'width {width}(train)')
            else:
                ax_2.plot(np.arange(1, width_2_stats[width].shape[0]) * stats_interval, 
                      width_2_stats[width][1:, keys[k]], '--', label=f'width {width}(valid)')
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    ax_2.set_ylabel('Error')
    
    return

# %%
plot_stats_hidden_dim(stats_hidden_dim_32, stats_hidden_dim_64, stats_hidden_dim_128, keys_hidden_dim_32, stats_interval)

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
stats_num_hidden_layer_1, keys_num_hidden_layer_1, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.5s to complete
#     error(train)=9.30e-01, acc(train)=7.36e-01, error(valid)=9.49e-01, acc(valid)=7.33e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 5.3s to complete
#     error(train)=7.36e-01, acc(train)=7.83e-01, error(valid)=7.73e-01, acc(valid)=7.70e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.9s to complete
#     error(train)=6.41e-01, acc(train)=8.05e-01, error(valid)=6.93e-01, acc(valid)=7.90e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.2s to complete
#     error(train)=5.72e-01, acc(train)=8.22e-01, error(valid)=6.36e-01, acc(valid)=8.01e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.1s to complete
#     error(train)=5.41e-01, acc(train)=8.29e-01, error(valid)=6.12e-01, acc(valid)=8.08e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.6s to complete
#     error(train)=4.99e-01, acc(train)=8.40e-01, error(valid)=5.82e-01, acc(valid)=8.10e-01
# ...

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
stats_num_hidden_layer_2, keys_num_hidden_layer_2, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 6.8s to complete
#     error(train)=7.38e-01, acc(train)=7.77e-01, error(valid)=7.63e-01, acc(valid)=7.68e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.9s to complete
#     error(train)=5.92e-01, acc(train)=8.12e-01, error(valid)=6.39e-01, acc(valid)=7.97e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.2s to complete
#     error(train)=5.07e-01, acc(train)=8.34e-01, error(valid)=5.67e-01, acc(valid)=8.17e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.5s to complete
#     error(train)=4.55e-01, acc(train)=8.48e-01, error(valid)=5.31e-01, acc(valid)=8.26e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.6s to complete
#     error(train)=4.20e-01, acc(train)=8.56e-01, error(valid)=5.13e-01, acc(valid)=8.34e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.6s to complete
#     error(train)=4.04e-01, acc(train)=8.61e-01, error(valid)=5.05e-01, acc(valid)=8.32e-01
# ...

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
stats_num_hidden_layer_3, keys_num_hidden_layer_3, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.8s to complete
#     error(train)=7.23e-01, acc(train)=7.65e-01, error(valid)=7.55e-01, acc(valid)=7.59e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.0s to complete
#     error(train)=5.80e-01, acc(train)=8.06e-01, error(valid)=6.36e-01, acc(valid)=7.92e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.0s to complete
#     error(train)=4.92e-01, acc(train)=8.34e-01, error(valid)=5.70e-01, acc(valid)=8.12e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.3s to complete
#     error(train)=4.41e-01, acc(train)=8.50e-01, error(valid)=5.39e-01, acc(valid)=8.24e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.3s to complete
#     error(train)=4.00e-01, acc(train)=8.60e-01, error(valid)=5.10e-01, acc(valid)=8.29e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.3s to complete
#     error(train)=3.93e-01, acc(train)=8.60e-01, error(valid)=5.15e-01, acc(valid)=8.31e-01
# ...

# %%
def plot_stats_num_hidden_layer(
        stats_num_hidden_layer_1, stats_num_hidden_layer_2, stats_num_hidden_layer_3, keys, stats_interval):
    
    depth_2_stats = {1: stats_num_hidden_layer_1, 2: stats_num_hidden_layer_2, 3: stats_num_hidden_layer_3}
    
    # Plot the change in the validation and training set accuracy over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        for depth in [1, 2, 3]:
            if k == 'acc(train)':
                ax_1.plot(np.arange(1, depth_2_stats[depth].shape[0]) * stats_interval, 
                  depth_2_stats[depth][1:, keys[k]], label=f'depth {depth}(train)')
            else:
                ax_1.plot(np.arange(1, depth_2_stats[depth].shape[0]) * stats_interval, 
                  depth_2_stats[depth][1:, keys[k]], '--', label=f'depth {depth}(valid)')
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')
    ax_1.set_ylabel('Accuracy')
    
    # Plot the change in the validation and training set error over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        for depth in [1, 2, 3]:
            if k == 'error(train)':
                ax_2.plot(np.arange(1, depth_2_stats[depth].shape[0]) * stats_interval, 
                      depth_2_stats[depth][1:, keys[k]], label=f'depth {depth}(train)')
            else:
                ax_2.plot(np.arange(1, depth_2_stats[depth].shape[0]) * stats_interval, 
                      depth_2_stats[depth][1:, keys[k]], '--', label=f'depth {depth}(valid)')
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    ax_2.set_ylabel('Error')
    
    return

# %%
plot_stats_num_hidden_layer(stats_num_hidden_layer_1, stats_num_hidden_layer_2, stats_num_hidden_layer_3,
                      keys_num_hidden_layer_1, stats_interval)

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, DropoutLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.0001
dropout = 0.7
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_dropout_1, keys_dropout_1, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.7s to complete
#     error(train)=3.83e+00, acc(train)=2.67e-02, error(valid)=3.84e+00, acc(valid)=2.56e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 5.4s to complete
#     error(train)=3.75e+00, acc(train)=3.91e-02, error(valid)=3.74e+00, acc(valid)=4.09e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 5.4s to complete
#     error(train)=3.62e+00, acc(train)=5.81e-02, error(valid)=3.61e+00, acc(valid)=6.06e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 6.2s to complete
#     error(train)=3.46e+00, acc(train)=7.86e-02, error(valid)=3.46e+00, acc(valid)=7.65e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 6.2s to complete
#     error(train)=3.35e+00, acc(train)=1.00e-01, error(valid)=3.34e+00, acc(valid)=1.05e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.6s to complete
#     error(train)=3.26e+00, acc(train)=1.14e-01, error(valid)=3.26e+00, acc(valid)=1.11e-01
# ...

# %%
# Setup hyperparameters
learning_rate = 0.0001
dropout = 0.9
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_dropout_2, keys_dropout_2, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.2s to complete
#     error(train)=3.85e+00, acc(train)=2.26e-02, error(valid)=3.85e+00, acc(valid)=2.12e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.3s to complete
#     error(train)=3.85e+00, acc(train)=2.55e-02, error(valid)=3.85e+00, acc(valid)=2.22e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.1s to complete
#     error(train)=3.85e+00, acc(train)=3.13e-02, error(valid)=3.85e+00, acc(valid)=3.13e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.0s to complete
#     error(train)=3.84e+00, acc(train)=3.96e-02, error(valid)=3.84e+00, acc(valid)=3.72e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.2s to complete
#     error(train)=3.83e+00, acc(train)=4.19e-02, error(valid)=3.83e+00, acc(valid)=4.25e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.2s to complete
#     error(train)=3.82e+00, acc(train)=4.23e-02, error(valid)=3.81e+00, acc(valid)=4.22e-02
# ...

# %%
# Setup hyperparameters
learning_rate = 0.0001
dropout = 0.95
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_dropout_3, keys_dropout_3, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.9s to complete
#     error(train)=3.85e+00, acc(train)=2.24e-02, error(valid)=3.85e+00, acc(valid)=1.97e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.7s to complete
#     error(train)=3.85e+00, acc(train)=2.33e-02, error(valid)=3.85e+00, acc(valid)=2.26e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.9s to complete
#     error(train)=3.85e+00, acc(train)=2.42e-02, error(valid)=3.85e+00, acc(valid)=2.23e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.9s to complete
#     error(train)=3.85e+00, acc(train)=2.43e-02, error(valid)=3.85e+00, acc(valid)=2.27e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.6s to complete
#     error(train)=3.85e+00, acc(train)=2.60e-02, error(valid)=3.85e+00, acc(valid)=2.44e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.8s to complete
#     error(train)=3.85e+00, acc(train)=2.65e-02, error(valid)=3.85e+00, acc(valid)=2.64e-02
# ...

# %%
def plot_stats_dropout(
        stats_dropout_1, stats_dropout_2, stats_dropout_3, keys, stats_interval):
    
    # Plot the validation accuracy and generalisation gap for each dropout value.
    fig = plt.figure(figsize=(8, 4))
    ax = fig.add_subplot(111)
    ax.plot([0.7, 0.9, 0.95],
            [stats_dropout_1[-1][3], stats_dropout_2[-1][3], stats_dropout_3[-1][3]],
            label='Val. Acc.')
    ax.plot([0.7, 0.9, 0.95],
            [abs(stats_dropout_1[-1][2]-stats_dropout_1[-1][0]),
             abs(stats_dropout_2[-1][2]-stats_dropout_2[-1][0]),
             abs(stats_dropout_3[-1][2]-stats_dropout_3[-1][0])],
            label='Gap')
    ax.legend(loc=0)
    ax.set_xlabel('Dropout value')
    ax.set_ylabel('Accuracy')
    
    return

# %%
plot_stats_dropout(stats_dropout_1, stats_dropout_2, stats_dropout_3,
                      keys_dropout_1, stats_interval)

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser
from mlp.penalties import L1Penalty

# Setup hyperparameters
learning_rate = 0.0001
penalty_coefficient = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
weights_penalty = L1Penalty(penalty_coefficient)
biases_penalty = L1Penalty(penalty_coefficient)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_l1_1, keys_l1_1, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 7.3s to complete
#     error(train)=1.34e+00, acc(train)=6.26e-01, error(valid)=1.34e+00, acc(valid)=6.23e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 6.9s to complete
#     error(train)=1.12e+00, acc(train)=6.84e-01, error(valid)=1.13e+00, acc(valid)=6.83e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 7.6s to complete
#     error(train)=9.99e-01, acc(train)=7.13e-01, error(valid)=1.01e+00, acc(valid)=7.12e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 7.2s to complete
#     error(train)=9.11e-01, acc(train)=7.36e-01, error(valid)=9.23e-01, acc(valid)=7.33e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 7.1s to complete
#     error(train)=8.47e-01, acc(train)=7.51e-01, error(valid)=8.60e-01, acc(valid)=7.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 7.3s to complete
#     error(train)=7.97e-01, acc(train)=7.63e-01, error(valid)=8.12e-01, acc(valid)=7.59e-01
# ...

# %%
# Setup hyperparameters
learning_rate = 0.0001
penalty_coefficient = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
weights_penalty = L1Penalty(penalty_coefficient)
biases_penalty = L1Penalty(penalty_coefficient)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_l1_2, keys_l1_2, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 7.7s to complete
#     error(train)=1.67e+00, acc(train)=5.60e-01, error(valid)=1.68e+00, acc(valid)=5.59e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 7.1s to complete
#     error(train)=1.53e+00, acc(train)=5.94e-01, error(valid)=1.53e+00, acc(valid)=5.89e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 7.7s to complete
#     error(train)=1.46e+00, acc(train)=6.08e-01, error(valid)=1.47e+00, acc(valid)=6.02e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 6.1s to complete
#     error(train)=1.41e+00, acc(train)=6.20e-01, error(valid)=1.42e+00, acc(valid)=6.14e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 6.3s to complete
#     error(train)=1.37e+00, acc(train)=6.29e-01, error(valid)=1.38e+00, acc(valid)=6.24e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 6.3s to complete
#     error(train)=1.34e+00, acc(train)=6.33e-01, error(valid)=1.35e+00, acc(valid)=6.31e-01
# ...

# %%
# Setup hyperparameters
learning_rate = 0.0001
penalty_coefficient = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
weights_penalty = L1Penalty(penalty_coefficient)
biases_penalty = L1Penalty(penalty_coefficient)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_l1_3, keys_l1_3, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 6.3s to complete
#     error(train)=3.85e+00, acc(train)=2.09e-02, error(valid)=3.85e+00, acc(valid)=1.84e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 6.3s to complete
#     error(train)=3.85e+00, acc(train)=2.15e-02, error(valid)=3.85e+00, acc(valid)=2.07e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 6.7s to complete
#     error(train)=3.85e+00, acc(train)=2.08e-02, error(valid)=3.85e+00, acc(valid)=2.01e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 6.7s to complete
#     error(train)=3.85e+00, acc(train)=2.14e-02, error(valid)=3.85e+00, acc(valid)=2.11e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 5.8s to complete
#     error(train)=3.85e+00, acc(train)=2.13e-02, error(valid)=3.85e+00, acc(valid)=2.28e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 5.3s to complete
#     error(train)=3.85e+00, acc(train)=2.14e-02, error(valid)=3.85e+00, acc(valid)=2.11e-02
# ...

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser
from mlp.penalties import L2Penalty

# Setup hyperparameters
learning_rate = 0.0001
penalty_coefficient = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
weights_penalty = L2Penalty(penalty_coefficient)
biases_penalty = L2Penalty(penalty_coefficient)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_l2_1, keys_l2_1, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.7s to complete
#     error(train)=1.34e+00, acc(train)=6.25e-01, error(valid)=1.34e+00, acc(valid)=6.19e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.8s to complete
#     error(train)=1.10e+00, acc(train)=6.88e-01, error(valid)=1.11e+00, acc(valid)=6.86e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.5s to complete
#     error(train)=9.68e-01, acc(train)=7.22e-01, error(valid)=9.82e-01, acc(valid)=7.19e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.5s to complete
#     error(train)=8.75e-01, acc(train)=7.46e-01, error(valid)=8.91e-01, acc(valid)=7.41e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.2s to complete
#     error(train)=8.11e-01, acc(train)=7.60e-01, error(valid)=8.27e-01, acc(valid)=7.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.2s to complete
#     error(train)=7.63e-01, acc(train)=7.71e-01, error(valid)=7.86e-01, acc(valid)=7.63e-01
# ...

# %%
# Setup hyperparameters
learning_rate = 0.0001
penalty_coefficient = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
weights_penalty = L2Penalty(penalty_coefficient)
biases_penalty = L2Penalty(penalty_coefficient)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_l2_2, keys_l2_2, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.1s to complete
#     error(train)=1.35e+00, acc(train)=6.25e-01, error(valid)=1.35e+00, acc(valid)=6.19e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.1s to complete
#     error(train)=1.13e+00, acc(train)=6.78e-01, error(valid)=1.14e+00, acc(valid)=6.75e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.2s to complete
#     error(train)=1.02e+00, acc(train)=7.10e-01, error(valid)=1.03e+00, acc(valid)=7.02e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.2s to complete
#     error(train)=9.29e-01, acc(train)=7.32e-01, error(valid)=9.48e-01, acc(valid)=7.25e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.0s to complete
#     error(train)=8.70e-01, acc(train)=7.45e-01, error(valid)=8.90e-01, acc(valid)=7.37e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.3s to complete
#     error(train)=8.15e-01, acc(train)=7.62e-01, error(valid)=8.37e-01, acc(valid)=7.56e-01
# ...

# %%
# Setup hyperparameters
learning_rate = 0.0001
penalty_coefficient = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
weights_penalty = L2Penalty(penalty_coefficient)
biases_penalty = L2Penalty(penalty_coefficient)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_l2_3, keys_l2_3, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.2s to complete
#     error(train)=3.84e+00, acc(train)=1.77e-01, error(valid)=3.84e+00, acc(valid)=1.75e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.0s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=2.01e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.1s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=1.98e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.2s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=1.98e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.1s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=2.01e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.1s to complete
#     error(train)=3.85e+00, acc(train)=2.17e-02, error(valid)=3.85e+00, acc(valid)=2.01e-02
# ...

# %%
def plot_stats_l1_and_l2(
        stats_l1_1, stats_l1_2, stats_l1_3, stats_l2_1, stats_l2_2, stats_l2_3, keys, stats_interval):
    
    # Plot the validation accuracy and generalisation gap for each weight decay value.
    fig = plt.figure(figsize=(8, 4))
    ax = fig.add_subplot(111)
    ax.plot([0.0001, 0.001, 0.1],
            [stats_l1_1[-1][3], stats_l1_2[-1][3], stats_l1_3[-1][3]],
            label='L1 Val. Acc.')
    ax.plot([0.0001, 0.001, 0.1],
            [stats_l2_1[-1][3], stats_l2_2[-1][3], stats_l2_3[-1][3]],
            '--',
            label='L2 Val. Acc.')
    ax.plot([0.0001, 0.001, 0.1],
            [abs(stats_l1_1[-1][2]-stats_l1_1[-1][0]),
             abs(stats_l1_2[-1][2]-stats_l1_2[-1][0]),
             abs(stats_l1_3[-1][2]-stats_l1_3[-1][0])],
            label='L1 Gap')
    ax.plot([0.0001, 0.001, 0.1],
            [abs(stats_l2_1[-1][2]-stats_l2_1[-1][0]),
             abs(stats_l2_2[-1][2]-stats_l2_2[-1][0]),
             abs(stats_l2_3[-1][2]-stats_l2_3[-1][0])],
            '--',
            label='L2 Gap')
    ax.legend(loc=0)
    ax.set_xlabel('Weight decay value')
    ax.set_ylabel('Accuracy')
    
    return

# %%
plot_stats_l1_and_l2(stats_l1_1, stats_l1_2, stats_l1_3,
                     stats_l2_1, stats_l2_2, stats_l2_3,
                     keys_l1_1, stats_interval)

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, DropoutLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser
from mlp.penalties import L1Penalty, L2Penalty

# Setup hyperparameters
learning_rate = 0.0001
dropout = 0.7
penalty_coefficient = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
weights_penalty = L2Penalty(penalty_coefficient)
biases_penalty = L2Penalty(penalty_coefficient)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_extra_1, keys_extra_1, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.8s to complete
#     error(train)=3.82e+00, acc(train)=2.53e-02, error(valid)=3.82e+00, acc(valid)=2.54e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 5.1s to complete
#     error(train)=3.71e+00, acc(train)=5.44e-02, error(valid)=3.70e+00, acc(valid)=5.56e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.6s to complete
#     error(train)=3.65e+00, acc(train)=6.75e-02, error(valid)=3.64e+00, acc(valid)=6.85e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.5s to complete
#     error(train)=3.56e+00, acc(train)=8.52e-02, error(valid)=3.55e+00, acc(valid)=8.87e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.7s to complete
#     error(train)=3.45e+00, acc(train)=1.02e-01, error(valid)=3.45e+00, acc(valid)=1.02e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.7s to complete
#     error(train)=3.35e+00, acc(train)=1.12e-01, error(valid)=3.35e+00, acc(valid)=1.10e-01
# ...

# %%
# Setup hyperparameters
learning_rate = 0.0001
dropout = 0.5
penalty_coefficient = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
weights_penalty = L2Penalty(penalty_coefficient)
biases_penalty = L2Penalty(penalty_coefficient)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_extra_2, keys_extra_2, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 5.3s to complete
#     error(train)=3.54e+00, acc(train)=9.11e-02, error(valid)=3.54e+00, acc(valid)=9.00e-02
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 4.9s to complete
#     error(train)=3.01e+00, acc(train)=1.74e-01, error(valid)=3.02e+00, acc(valid)=1.72e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 4.7s to complete
#     error(train)=2.74e+00, acc(train)=2.25e-01, error(valid)=2.74e+00, acc(valid)=2.22e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 4.8s to complete
#     error(train)=2.55e+00, acc(train)=2.67e-01, error(valid)=2.56e+00, acc(valid)=2.65e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 4.7s to complete
#     error(train)=2.42e+00, acc(train)=3.01e-01, error(valid)=2.41e+00, acc(valid)=3.02e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 4.6s to complete
#     error(train)=2.30e+00, acc(train)=3.27e-01, error(valid)=2.30e+00, acc(valid)=3.24e-01
# ...

# %%
# Setup hyperparameters
learning_rate = 0.0001
dropout = 0.3
penalty_coefficient = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
weights_penalty = L2Penalty(penalty_coefficient)
biases_penalty = L2Penalty(penalty_coefficient)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_extra_3, keys_extra_3, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 7.1s to complete
#     error(train)=2.73e+00, acc(train)=2.45e-01, error(valid)=2.75e+00, acc(valid)=2.38e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 6.4s to complete
#     error(train)=2.22e+00, acc(train)=3.66e-01, error(valid)=2.23e+00, acc(valid)=3.59e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 7.1s to complete
#     error(train)=1.96e+00, acc(train)=4.29e-01, error(valid)=1.97e+00, acc(valid)=4.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 7.2s to complete
#     error(train)=1.80e+00, acc(train)=4.72e-01, error(valid)=1.80e+00, acc(valid)=4.74e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 6.7s to complete
#     error(train)=1.68e+00, acc(train)=5.06e-01, error(valid)=1.68e+00, acc(valid)=5.04e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 6.8s to complete
#     error(train)=1.59e+00, acc(train)=5.28e-01, error(valid)=1.58e+00, acc(valid)=5.30e-01
# ...

# %%
# Setup hyperparameters
learning_rate = 0.0001
dropout = 0.0001
penalty_coefficient = 0.0001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
weights_penalty = L2Penalty(penalty_coefficient)
biases_penalty = L2Penalty(penalty_coefficient)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty),
    DropoutLayer(rng=rng, incl_prob=dropout),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init, weights_penalty=weights_penalty, biases_penalty=biases_penalty)
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
stats_extra_4, keys_extra_4, _, _, _, _, _ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 4.0s to complete
#     error(train)=1.34e+00, acc(train)=6.25e-01, error(valid)=1.35e+00, acc(valid)=6.21e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 3.6s to complete
#     error(train)=1.12e+00, acc(train)=6.82e-01, error(valid)=1.12e+00, acc(valid)=6.80e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28484/3886911439.py in <module>
#      30
#      31 # Remember to use notebook=False when you write a script to be run in a terminal
# ---> 32 stats_extra_4, keys_extra_4, _, _, _, _, _ = train_model_and_plot_stats(
#      33     model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
#
# ...

# %%
def plot_stats_extra(
        stats_extra_1, stats_extra_2, stats_extra_3, stats_extra_4, stats_extra_5, stats_extra_6, keys, stats_interval):
    
    # Plot the validation accuracy and generalisation gap for each weight decay value.
    fig = plt.figure(figsize=(8, 4))
    ax = fig.add_subplot(111)
    xs = [stats_extra_1[-1][2]-stats_extra_1[-1][0],
          stats_extra_2[-1][2]-stats_extra_2[-1][0],
          stats_extra_3[-1][2]-stats_extra_3[-1][0],
          stats_extra_4[-1][2]-stats_extra_4[-1][0],
          stats_extra_5[-1][2]-stats_extra_5[-1][0],
          stats_extra_6[-1][2]-stats_extra_6[-1][0]]
    ys = [stats_extra_1[-1][3],stats_extra_2[-1][3],
          stats_extra_3[-1][3],stats_extra_4[-1][3],
          stats_extra_5[-1][3],stats_extra_6[-1][3]]
    ax.scatter(xs, ys)
    labels = ['0.7, L1 1e-4', '0.5, L1 1e-4']
    for i in range(6):
        ax.annotate(labels[i], (xs[i], ys[i]))
    ax.legend(loc=0)
    ax.set_xlabel('Generalisation gap')
    ax.set_ylabel('Validation accuracy')
    
    return
